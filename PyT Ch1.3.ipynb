# %%
# !ls
# Out:
# PyT Ch1.3.ipynb small

# %%
import nibabel as nib
working_dir_1 = "./small/t1/"
working_dir_2 = "./small/t2/"
filename_1 = "IXI167-HH-1569-T1_fcm.nii.gz"
filename_2 = "IXI167-HH-1569-T2_reg_fcm.nii.gz"
image_1 = nib.load( working_dir_1 + filename_1)
image_2 = nib.load( working_dir_2 + filename_2)
image_data_1 = image_1.get_fdata()
image_data_2= image_2.get_fdata()
image_data_1.shape
# Out:
# (120, 120, 90)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt


plt.imshow(image_data_1[:,:,45])
print("T1")
plt.show()

print("T2")
plt.imshow(image_data_2[:,:,45])
plt.show()
# Out:
# T1
# T2
